# %%
# !pip install pandas

import pandas as pd

# %%
# !pip install plotly

# %%
student_stats=pd.read_csv('StudentsPerformance.csv')
student_stats=student_stats.rename(columns={'math score':'math_score'})
student_stats
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math_score  reading score  writing score
# ...

# %%
mean_scores=student_stats.groupby(['gender','race/ethnicity'], as_index=False)\
.aggregate({'math_score':'mean', 'reading score':'mean'}) \
.rename(columns={'math_score':'mean_math_score', 'reading score':'mean_reading_score'})

# %%
mean_scores
# Out:
#    gender race/ethnicity  mean_math_score  mean_reading_score
# 0  female        group A        58.527778           69.000000
# 1  female        group B        61.403846           71.076923
# 2  female        group C        62.033333           71.944444
# 3  female        group D        65.248062           74.046512
# 4  female        group E        70.811594           75.840580
# 5    male        group A        63.735849           61.735849
# 6    male        group B        65.930233           62.848837
# 7    male        group C        67.611511           65.424460
# 8    male        group D        69.413534           66.135338
# 9    male        group E        76.746479           70.295775

# %%
student_stats.groupby(['gender','race/ethnicity']).math_score.nunique()
# Out:
# gender  race/ethnicity
# female  group A           29
#         group B           51
#         group C           59
#         group D           53
#         group E           44
# male    group A           38
#         group B           43
#         group C           56
#         group D           49
#         group E           38
# Name: math_score, dtype: int64

# %%
student_stats.sort_values(['gender', 'math_score'], ascending=False) \
.groupby('gender').head()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 114  female        group E           bachelor's degree      standard
# 263  female        group E                 high school      standard
#
#     test preparation course  math_score  reading score  writing score
# 149               completed         100            100             93
# ...

# %%
student_stats['total_score']=student_stats.math_score+student_stats['reading score']+student_stats['writing score']

# %%
student_stats
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math_score  reading score  writing score  \
# ...

# %%
import numpy as np

# %%
student_stats=student_stats.assign(total_score_log=np.log(student_stats.total_score))

# %%
student_stats
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math_score  reading score  writing score  \
# ...

# %%
dota=pd.read_csv('dota_hero_stats.csv')

# %%
dota
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
dota.groupby(['legs'])['name'].nunique()
# Out:
# legs
# 0    11
# 2    95
# 4     7
# 6     3
# 8     1
# Name: name, dtype: int64

# %%
accountancy=pd.read_csv('accountancy.csv')

# %%
accountancy
# Out:
#     Unnamed: 0 Executor Type  Salary
# 0            0     Pupa    D      63
# 1            1     Pupa    A     158
# 2            2     Pupa    D     194
# 3            3     Pupa    E     109
# 4            4    Loopa    E     184
# 5            5    Loopa    F     232
# 6            6    Loopa    B     249
# 7            7     Pupa    F     195
# 8            8     Pupa    A     115
# 9            9     Pupa    E      65
# 10          10    Loopa    C     145
# 11          11    Loopa    D     149
# 12          12    Loopa    B      50
# 13          13     Pupa    A     217
# 14          14    Loopa    D     110
# 15          15     Pupa    F      62
# 16          16     Pupa    A      55
# 17          17    Loopa    B     190
# 18          18    Loopa    E      83
# 19          19     Pupa    A     234
# 20          20    Loopa    E     156
# 21          21    Loopa    E     219
# 22          22     Pupa    C      55
# 23          23     Pupa    D     144
# ...

# %%
accountancy.groupby(['Type','Executor' ])['Salary'].mean()
# Out:
# Type  Executor
# A     Loopa        58.000000
#       Pupa        160.833333
# B     Loopa       145.166667
#       Pupa         77.000000
# C     Loopa       154.333333
#       Pupa         74.500000
# D     Loopa       137.714286
#       Pupa        146.500000
# E     Loopa       164.000000
#       Pupa        131.200000
# F     Loopa       238.000000
#       Pupa        136.250000
# Name: Salary, dtype: float64

# %%
dota.groupby(['attack_type', 'primary_attr']).name.nunique()
# Out:
# attack_type  primary_attr
# Melee        agi             19
#              int              2
#              str             35
# Ranged       agi             18
#              int             40
#              str              3
# Name: name, dtype: int64

# %%
algae=pd.read_csv('algae.csv')
algae
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
algae.groupby('genus').mean()
# Out:
#               sucrose    alanin   citrate   glucose  oleic_acid
# genus
# Ascophyllum  6.825467  0.875429  5.253527  3.414961    2.432526
# Cladophora   4.008792  3.997055  5.288311  2.800276    2.263472
# Fucus        4.355112  3.566411  4.214878  2.814803    3.367647
# Palmaria     0.704580  3.176440  5.573905  3.242090    2.245538
# Saccharina   4.183596  3.524207  3.346710  4.980594    4.487252

# %%
algae.query('genus=="Fucus"').describe()
# Out:
#         sucrose    alanin   citrate   glucose  oleic_acid
# count  3.000000  3.000000  3.000000  3.000000    3.000000
# mean   4.355112  3.566411  4.214878  2.814803    3.367647
# std    2.110570  3.149943  2.691679  0.713559    3.050376
# min    3.001472  0.346431  1.216767  2.272724    0.304573
# 25%    3.139171  2.028965  3.110515  2.410591    1.848888
# 50%    3.276870  3.711498  5.004262  2.548459    3.393203
# 75%    5.031933  5.176401  5.713934  3.085842    4.899184
# max    6.786996  6.641303  6.423606  3.623225    6.405165

# %%
algae.groupby('group').aggregate(np.ptp)
# Out:
#         sucrose    alanin   citrate   glucose  oleic_acid
# group
# brown  5.189345  6.294872  5.351686  3.740495    6.100592
# green  3.259662  5.232574  3.857763  1.026753    1.396502
# red    0.000000  0.000000  0.000000  0.000000    0.000000

# %%
algae.groupby('group').species.nunique()
# Out:
# group
# brown    6
# green    3
# red      1
# Name: species, dtype: int64

# %%
#%matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
student_stats.plot.scatter(x='math_score', y='reading score')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-c6a561aa7660> in <module>
#       1 #%matplotlib inline
# ----> 2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
#       4 student_stats.plot.scatter(x='math_score', y='reading score')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
ax=sns.lmplot(x='math_score', y='reading score', hue='gender', data=student_stats,fit_reg=False)
ax.set_xlabels('math score')
ax.set_ylabels('reading score')

# %%
df=pd.read_csv('income.csv')
df

# %%
df.plot()

# %%
sns.lineplot(x=df.index, y=df.income)

# %%
sns.lineplot(data=df)

# %%
df['income'].plot()

# %%
plt.plot(df.index, df.income)

# %%
df.plot(kind='line')

# %%
df.income.plot()

# %%
df1=pd.read_csv('dataset_209770_6.txt', sep=" ")
df1.head()

# %%
df1.plot.scatter(x='x', y='y')

# %%
df2=pd.read_csv('genome_matrix.csv', index_col=0)
df2.head()

# %%
g = sns.heatmap(data=df2,cmap="viridis")# ваш код для создания теплокарты, укажите параметр cmap="viridis" для той же цветовой схемы
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
dota.head()

# %%
dota['num_r']=[len(x.split()) for x in dota['roles'].tolist()]

# %%
dota

# %%
dota.num_r.hist()

# %%
iris=pd.read_csv('iris.csv', index_col=0)
iris.head()

# %%
for column in iris:
    ax=sns.distplot(iris[column], label=column)
    ax.legend()

# %%
sns.violinplot(data=iris, x='petal length')

# %%
sns.pairplot(data=iris )

# %%
my_stat = pd.read_csv('my_stat.csv')
my_stat.head()

# %%
subset_1=my_stat[['V1', 'V3']].loc[0:9]
subset_2=my_stat[['V2', 'V4']].drop([1,5], axis=0)

# %%
subset_2

# %%
subset_1=my_stat.query('V1>0 and V3=="A"')
subset_2=my_stat.query('V4>=1 and V2!=10')

# %%
subset_2
subset_1

# %%
my_stat['V5']=my_stat.V1+my_stat.V4

# %%
my_stat['V6']=np.log(my_stat.V2)

# %%
my_stat.rename(columns={'V1':'session_value', 'V2':'group', 
                      'V3':'time', 'V4':'n_users'})

# %%
my_stat1=pd.read_csv('my_stat_1.csv')

# %%
my_stat1

# %%
my_stat1.session_value=my_stat1.session_value.fillna(0)

# %%
my_stat1.n_users

# %%
my_stat1.n_users=my_stat1.n_users.astype('int')

# %%
t1=my_stat1.query('n_users>=0').n_users.median()

# %%
my_stat1.loc[my_stat1['n_users'] < 0, 'n_users'] = t1

# %%
my_stat1

# %%
my_stat1.groupby('group',as_index=False)['session_value'].agg('mean').rename(columns={'session_value':'mean_session_value'})
